# %% [markdown]
# ## This notebook will guide on how to use WBGAPI to collect and process world Bank data

# %%
# First we need to import all the things
import wbgapi as wb   # I use wb as a namespace in all my work
import pandas as pd   # optional but highly recommended for wbgapi
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Querying and Searching
# ##### The info functions are the primary tool for searching the API. You can limit the response by calling info() with identifiers (a single value or lists) or by adding a keyword search.
# ##### wb.source.info() # especially useful for seeing what databases are available
# ##### wb.series.info()
# ##### wb.economy.info('CAN')
# ##### wb.economy.info(['USA', 'MEX', 'ARG'])
# ##### wb.series.info(q='co2')
# ##### wb.economy.info(q='korea')

# %%
wb.series.info(q='co2')
# Out:
# id                    value
# --------------------  ---------------------------------------------------------------------------------------------------------------------------------
# EN.ATM.CO2E.EG.ZS     CO2 intensity (kg per kg of oil equivalent energy use)
# EN.ATM.CO2E.GF.KT     CO2 emissions from gaseous fuel consumption (kt)
# EN.ATM.CO2E.GF.ZS     CO2 emissions from gaseous fuel consumption (% of total)
# EN.ATM.CO2E.KD.GD     CO2 emissions (kg per 2015 US$ of GDP)
# EN.ATM.CO2E.KT        CO2 emissions (kt)
# EN.ATM.CO2E.LF.KT     CO2 emissions from liquid fuel consumption (kt)
# EN.ATM.CO2E.LF.ZS     CO2 emissions from liquid fuel consumption (% of total)
# EN.ATM.CO2E.PC        CO2 emissions (metric tons per capita)
# EN.ATM.CO2E.PP.GD     CO2 emissions (kg per PPP $ of GDP)
# EN.ATM.CO2E.PP.GD.KD  CO2 emissions (kg per 2017 PPP $ of GDP)
# EN.ATM.CO2E.SF.KT     CO2 emissions from solid fuel consumption (kt)
# EN.ATM.CO2E.SF.ZS     CO2 emissions from solid fuel consumption (% of total)
# EN.CO2.BLDG.ZS        CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)
# EN.CO2.ETOT.ZS        CO2 emissions from electricity and heat production, total (% of total fuel combustion)
# EN.CO2.MANF.ZS        CO2 emissions from manufacturing industries and construction (% of total fuel combustion)
# EN.CO2.OTHX.ZS        CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)
# EN.CO2.TRAN.ZS        CO2 emissions from transport (% of total fuel combustion)
#                       17 elements

# %%
wb.search(q='co2', brief=False)
# Out:
# ========
# Series: EN.ATM.CO2E.EG.ZS, CO2 intensity (kg per kg of oil equivalent energy use)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 intensity (kg per kg of oil equivalent energy use)
# ========
# Series: EN.ATM.CO2E.GF.KT, CO2 emissions from gaseous fuel consumption (kt)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from gaseous fuel consumption (kt)
# ========
# Series: EN.ATM.CO2E.GF.ZS, CO2 emissions from gaseous fuel consumption (% of total)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from gaseous fuel consumption (% of total)
# ========
# Series: EN.ATM.CO2E.KD.GD, CO2 emissions (kg per 2015 US$ of GDP)
#
# IndicatorName: CO2 emissions (kg per 2015 US$ of GDP)
# ========
# Series: EN.ATM.CO2E.KT, CO2 emissions (kt)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions (kt)
# ========
# Series: EN.ATM.CO2E.LF.KT, CO2 emissions from liquid fuel consumption (kt)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from liquid fuel consumption (kt)
# ========
# Series: EN.ATM.CO2E.LF.ZS, CO2 emissions from liquid fuel consumption (% of total)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from liquid fuel consumption (% of total)
# ========
# Series: EN.ATM.CO2E.PC, CO2 emissions (metric tons per capita)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions (metric tons per capita)
# ========
# Series: EN.ATM.CO2E.PP.GD, CO2 emissions (kg per PPP $ of GDP)
#
# IndicatorName: CO2 emissions (kg per PPP $ of GDP)
# ========
# Series: EN.ATM.CO2E.PP.GD.KD, CO2 emissions (kg per 2017 PPP $ of GDP)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions (kg per 2017 PPP $ of GDP)
# ========
# Series: EN.ATM.CO2E.SF.KT, CO2 emissions from solid fuel consumption (kt)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from solid fuel consumption (kt)
# ========
# Series: EN.ATM.CO2E.SF.ZS, CO2 emissions from solid fuel consumption (% of total)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from solid fuel consumption (% of total)
# ========
# Series: EN.ATM.GHGO.KT.CE, Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ...10-mee GWP=1300, SF6 GWP=23900). Derived as residuals from total GHG emissions, CO2 emissions, CH4 emissions, and N2O emissions in kt of CO equivalent. Other...
# ========
# Series: EN.ATM.GHGO.ZG, Other greenhouse gas emissions (% change from 1990)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# Statisticalconceptandmethodology: ...10-mee GWP=1300, SF6 GWP=23900). Derived as residuals from total GHG emissions, CO2 emissions, CH4 emissions, and N2O emissions in kt of CO equivalent. Other...
# ========
# Series: EN.ATM.GHGT.KT.CE, Total greenhouse gas emissions (kt of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Total greenhouse gas emissions (kt of CO2 equivalent)
# --------
# Longdefinition: ...Total greenhouse gas emissions in kt of CO2 equivalent are composed of CO2 totals excluding short-cycle biomass burning (such as agricultural waste...
# --------
# Statisticalconceptandmethodology: ...The GHG totals are expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.GHGT.ZG, Total greenhouse gas emissions (% change from 1990)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# Longdefinition: ...Total greenhouse gas emissions are composed of CO2 totals excluding short-cycle biomass burning (such as agricultural waste...
# --------
# Statisticalconceptandmethodology: ...The GHG totals are expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.HFCG.KT.CE, HFC gas emissions (thousand metric tons of CO2 equivalent)
#
# IndicatorName: HFC gas emissions (thousand metric tons of CO2 equivalent)
# ========
# Series: EN.ATM.METH.AG.KT.CE, Agricultural methane emissions (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ...IPCC category 4 = Agriculture. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.METH.AG.ZS, Agricultural methane emissions (% of total)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# ========
# Series: EN.ATM.METH.EG.KT.CE, Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ...IPCC category 1 = Energy. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.METH.EG.ZS, Energy related methane emissions (% of total)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# ========
# Series: EN.ATM.METH.KT.CE, Methane emissions (kt of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Methane emissions (kt of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ...such as agriculture and from industrial methane production. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.METH.PC, Methane emissions (metric tons of CO2 equivalent per capita)
#
# IndicatorName: Methane emissions (metric tons of CO2 equivalent per capita)
# ========
# Series: EN.ATM.METH.ZG, Methane emissions (% change from 1990)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# Statisticalconceptandmethodology: ...such as agriculture and from industrial methane production. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.NOXE.AG.KT.CE, Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ... on-site), and savannah burning. IPCC category 4 = Agriculture. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.NOXE.AG.ZS, Agricultural nitrous oxide emissions (% of total)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# Statisticalconceptandmethodology: ... on-site), and savannah burning. IPCC category 4 = Agriculture. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.NOXE.EG.KT.CE, Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# --------
# Statisticalconceptandmethodology: ...IPCC category 1 = Energy. Expressed in CO2 equivalent using the GWP100 metric of the Second Assessment Report of IPCC and...
# ========
# Series: EN.ATM.NOXE.EG.ZS, Nitrous oxide emissions in energy sector (% of total)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# ========
# Series: EN.ATM.NOXE.KT.CE, Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# --------
# IndicatorName: Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# ========
# Series: EN.ATM.NOXE.PC, Nitrous oxide emissions (metric tons of CO2 equivalent per capita)
#
# IndicatorName: Nitrous oxide emissions (metric tons of CO2 equivalent per capita)
# ========
# Series: EN.ATM.NOXE.ZG, Nitrous oxide emissions (% change from 1990)
#
# Developmentrelevance: ...related effects on climate, sea level rise and world agriculture. Emissions of CO2 are from burning oil, coal and gas for energy use, burning wood and waste...
# ========
# Series: EN.ATM.PFCG.KT.CE, PFC gas emissions (thousand metric tons of CO2 equivalent)
#
# IndicatorName: PFC gas emissions (thousand metric tons of CO2 equivalent)
# ========
# Series: EN.ATM.SF6G.KT.CE, SF6 gas emissions (thousand metric tons of CO2 equivalent)
#
# IndicatorName: SF6 gas emissions (thousand metric tons of CO2 equivalent)
# ========
# Series: EN.CLC.GHGR.MT.CE, GHG net emissions/removals by LUCF (Mt of CO2 equivalent)
#
# IndicatorName: GHG net emissions/removals by LUCF (Mt of CO2 equivalent)
# --------
# Longdefinition: ...change activities, including but not limited to (1) emissions and removals of CO2 from decreases or increases in biomass stocks due to forest management, logging...
# ========
# Series: EN.CO2.BLDG.MT, CO2 emissions from residential buildings and commercial and public services (million metric tons)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from residential buildings and commercial and public services ...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from residential buildings and commercial and public services...
# ========
# Series: EN.CO2.BLDG.ZS, CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from residential buildings and commercial and public services (% of...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from residential buildings and commercial and public services...
# ========
# Series: EN.CO2.ETOT.MT, CO2 emissions from electricity and heat production, total (million metric tons)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from electricity and heat production, total (million metric tons)
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from electricity and heat production is the sum of three IEA...
# ========
# Series: EN.CO2.ETOT.ZS, CO2 emissions from electricity and heat production, total (% of total fuel combustion)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from electricity and heat production, total (% of total fuel...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from electricity and heat production is the sum of three IEA...
# ========
# Series: EN.CO2.MANF.MT, CO2 emissions from manufacturing industries and construction (million metric tons)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from manufacturing industries and construction (million metric tons)
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from manufacturing industries and construction contains the emissions...
# ========
# Series: EN.CO2.MANF.ZS, CO2 emissions from manufacturing industries and construction (% of total fuel combustion)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from manufacturing industries and construction (% of total fuel...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from manufacturing industries and construction contains the emissions...
# ========
# Series: EN.CO2.OTHX.MT, CO2 emissions from other sectors, excluding residential buildings and commercial and public services (million metric tons)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from other sectors, excluding residential buildings and commercial...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from other sectors, less residential buildings and commercial and...
# ========
# Series: EN.CO2.OTHX.ZS, CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: ...CO2 emissions from other sectors, excluding residential buildings and commercial...
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from other sectors, less residential buildings and commercial and...
# ========
# Series: EN.CO2.TRAN.MT, CO2 emissions from transport (million metric tons)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from transport (million metric tons)
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from transport contains emissions from the combustion of fuel for all...
# ========
# Series: EN.CO2.TRAN.ZS, CO2 emissions from transport (% of total fuel combustion)
#
# Developmentrelevance: ...Carbon dioxide (CO2) is naturally occurring gas fixed by photosynthesis into organic matter. A...
# --------
# IndicatorName: CO2 emissions from transport (% of total fuel combustion)
# --------
# Limitationsandexceptions: ...for fuel combustion is largely based on energy balances, the IEA estimates for CO2 from fuel combustion have been calculated using the IEA energy balances and the...
# --------
# Longdefinition: ...CO2 emissions from transport contains emissions from the combustion of fuel for all...

# %%
wb.search('pound')
# Out:
# ========
# Country: CHI, Channel Islands
#
# CurrencyUnit: Pound sterling
# ========
# Country: EGY, Egypt, Arab Rep.
#
# CurrencyUnit: Egyptian pound
# ========
# Country: GBR, United Kingdom
#
# CurrencyUnit: Pound sterling
# ========
# Country: GIB, Gibraltar
#
# CurrencyUnit: Gibraltar pound
# ========
# Country: IMN, Isle of Man
#
# CurrencyUnit: Pound sterling
# ========
# Country: IRL, Ireland
#
# SpecialNotes: ...rate was adopted by the EU Council on January 1, 1999: 1 euro = 0.787564 Irish pound. Please note that historical data before 1999 are not actual euros and are not...
# ========
# Country: LBN, Lebanon
#
# CurrencyUnit: Lebanese pound
# ========
# Country: SDN, Sudan
#
# CurrencyUnit: Sudanese pound
# ========
# Country: SSD, South Sudan
#
# CurrencyUnit: South Sudanese Pound
# ========
# Country: SYR, Syrian Arab Republic
#
# CurrencyUnit: Syrian pound
# ========
# Series: DT.CUR.UKPS.ZS, Currency composition of PPG debt, Pound sterling (%)
#
# IndicatorName: Currency composition of PPG debt, Pound sterling (%)
# --------
# Longdefinition: ...of external long-term public and publicly-guaranteed debt contracted in U.K. pound sterling for the low- and middle-income countries....
# --------
# Shortdefinition: ...of external long-term public and publicly-guaranteed debt contracted in U.K. pound sterling for the low- and middle-income countries....
# ========
# Series: IS.SHP.DHL1.CD.IB.US, Cost to ship 1lb priority express air package through DHL from the United States (current US$)
#
# Longdefinition: ...is the DHL international U.S. outbound worldwide priority express rate for a 1 pound nondocument air package. Fuel, assessorial/surcharges, duties, and taxes are...
# --------
# Statisticalconceptandmethodology: ...The data is the cost to ship a 1 pound priority air package from the United States using DHL's Express Worldwide...
# ========
# Series: IS.SHP.DHL1.CD.OB.US, Cost to ship 1kg priority express air package through DHL to the United States (current US$)
#
# Statisticalconceptandmethodology: ...billed weight. The actual weight uses a standard scale rounded to the next full pound. The dimensional weight uses the International Air Transport Association (IATA)...
